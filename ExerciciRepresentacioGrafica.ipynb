# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = 'insurance.csv'
insurance_data = pd.read_csv(file_path)

# %%
insurance_data.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
insurance_data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# - Quina regió té l’observació 4?
#   - northwest

# %% [markdown]
# - Quin valor bmi mostra l’observació 2?
#   - 33.000

# %% [markdown]
# - L’observació 3 té sexe femení o masculí?
#   - male

# %% [markdown]
# - Quin cost (charge) té l’observació 1?
#   - 1725.55230

# %%
insurance_data.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %% [markdown]
# - Quantes observacions hi ha a la taula?
#   - 1388

# %% [markdown]
# - Quina és la desviació std de la columna bmi?
#   - 6.098187

# %% [markdown]
# - Quin és el cost (charges) mínim que té la taula?
#   - 1121.873900

# %% [markdown]
# - Quin és el nombre màxim de fills o filles que pot tenir una observació concreta?
#   - 5

# %% [markdown]
# - Genera un histograma per a la variable edats (age) i la variable cost (charge).

# %%
insurance_data['age'].hist()
# Out:
# <AxesSubplot:>

# %%
insurance_data['charges'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# - Fes un gràfic de dispersió del cost (charges) davant de bmi i diferencia els punts obtinguts, depenent, primer, de si la persona és fumadora o no i, després, de si és de sexe masculí o femení.

# %%
sns.scatterplot(x=insurance_data['bmi'], y=insurance_data['charges'], hue=insurance_data['smoker'])
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='charges'>

# %%
sns.scatterplot(x=insurance_data['bmi'],y=insurance_data['charges'], hue=insurance_data['sex'])
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='charges'>

# %% [markdown]
# - Crea un gràfic de dispersió dels valors bmi en relació, primer, amb el nombre de fills o filles (children) i, després, amb el sexe i, finalment, amb si fuma o no. Tingues present que hi ha una funció específica per crear gràfics de dispersió en els quals una variable és categòrica. El nombre de fills o filles, el sexe i si fuma o no ho són.

# %%
sns.lmplot(x='bmi', y='charges', hue='sex', data=insurance_data)

# %%
sns.swarmplot(x=insurance_data['children'], y=insurance_data['bmi'])
# Out:
# /home/jesus/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 61.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/jesus/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 41.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/jesus/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 28.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/jesus/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 14.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='children', ylabel='bmi'>

# %%
sns.swarmplot(x=insurance_data['sex'], y=insurance_data['bmi'])
# Out:
# /home/jesus/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 18.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/jesus/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 21.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='sex', ylabel='bmi'>

# %%
sns.swarmplot(x=insurance_data['smoker'], y=insurance_data['bmi'])
# Out:
# /home/jesus/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 39.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='smoker', ylabel='bmi'>
